# %% [markdown]
# # 🚀 YOLOv8x Fine-Tuning on Google Colab (1280x1664 Optimized)
# This notebook will mount your Google Drive, install the dependencies, and run the standalone fine-tuning script.
#
# **Instructions:**
# 1. Ensure you have uploaded the `Fine-tuning` folder to your Google Drive.
# 2. Ensure you have selected a high-VRAM GPU (like **A100**) from the *Runtime -> Change runtime type* menu.
# 3. Run the cells below sequentially.

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
    # 2. Install Dependencies
    # Note: We install ultralytics to get all dependencies, but we use the local folder for 6-channel logic
    # !pip install ultralytics paddleocr PyMuPDF pyyaml tqdm

# %%
# 3. Navigate to your Fine-tuning folder
# Adjust this path to match exactly where you uploaded the folder in your Google Drive
# %cd /content/drive/MyDrive/Internship/Invoice Intelligence Document/YOLOv8x/Fine-tuning
# !ls

# %%
# 4. Start Fine-Tuning
# This script will use the 6-channel warm start and 1280x1664 resolution
# !python run_training.py
